# %% [markdown]
# #### Option 1

# %%
import cv2
import numpy as np

################
### FUNCTION ###
################
drawing = False

x2 = 0
y2 = 0
color = (255,0,0)
size = 2
def draw_circle(event,x,y,flags,param):
    
    global drawing, x2, y2, color, size
    
    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing == True:
            
            
            if(x2 != 0 and y2 != 0):
                if(x2 - x != 0):
                    k = (y2 - y) / (x2 - x)
                    b = y2 - k*x2
                    if(abs(x2 - x) > abs(y2 - y)):
                        for i in range(min(x2, x) + 1, max(x2, x)):
                            cv2.circle(img,(i,round(k * i + b)),size,color,-1)
                    else:
                        for i in range(min(y2, y) + 1, max(y2, y)):
                            cv2.circle(img,(round((i - b) / k), i),size,color,-1)
                else:
                    cv2.line(img, (x,y), (x2,y2),color,size)
            x2 = x
            y2 = y 
    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
        cv2.circle(img,(x,y),size,color,-1)
        x2 = 0
        y2 = 0
    
             

cv2.namedWindow(winname='my_frame')

cv2.setMouseCallback('my_frame',draw_circle)

#################################
### SHOWING IMAGE WITH OPENCV ###
#################################

img = np.full((350 * 2,512 * 2,3), 255, np.uint8)
while True:
    
    cv2.imshow('my_frame', img)
    k = cv2.waitKey(20)
    if k == 27:
        break
    elif k == 98:
        color = (255,0,0)
    elif k == 8:
        color = (255,255,255)
    elif k == 121:
        color = (0,255,255)
    elif k == 114:
        color = (0,0,255)
    elif k == 103: 
        color = (0,255,0)
    
    
    if(color == (255,255,255)):
        size = 10
    else:
        size = 2
cv2.destroyAllWindows()

# %% [markdown]
# #### Option 2

# %%
import cv2
import numpy as np

################
### FUNCTION ###
################
drawing = False


def draw_circle(event,x,y,flags,param):
    
    global drawing
    
    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing == True:
            cv2.circle(img,(x,y),2,(0,255,0),-1)
            
            
    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
        cv2.circle(img,(x,y),2,(0,255,0),-1)
        
    
             

cv2.namedWindow(winname='my_frame')

cv2.setMouseCallback('my_frame',draw_circle)

#################################
### SHOWING IMAGE WITH OPENCV ###
#################################

img = np.zeros((512,512,3), np.uint8)

while True:
    
    cv2.imshow('my_frame', img)
    
    if cv2.waitKey(20) & 0xFF == 27:
        break

cv2.destroyAllWindows()
